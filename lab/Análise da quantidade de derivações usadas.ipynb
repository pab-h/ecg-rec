# %% [markdown]
# Análise da quantidade de derivações usadas

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv("../dist/r2.scores.csv")

df.head()

# %%
df_agg = df.groupby("n_derivations").mean()

df_agg = df_agg.drop(columns = ["exam_id"])

df_agg.head(10)

# %%
df_agg.to_csv("../dist/r2.scores.agg.csv")
