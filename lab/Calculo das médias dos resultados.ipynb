# %% [markdown]
# Cálculo das médias dos resultados

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
pd.set_option("display.float_format", "{:.4f}".format)

# %%
corr_dataset = pd.read_csv("../dist/attempts/09/corr.scores.csv")
mae_dataset  = pd.read_csv("../dist/attempts/09/mae.scores.csv")
r2_dataset   = pd.read_csv("../dist/attempts/09/r2.scores.csv")

# %%
round(corr_dataset.mean(), 4)

# %%
round(mae_dataset.mean(), 4)

# %%
round(r2_dataset.mean(), 4)
